# %%
import gym
#create eviornment
env = gym.make('CartPole-v0')

# %% [markdown]
# # Q learning
# ### Agent design and Neural Model
# #### 1) The agent needs memory because it does not have any training data
# #### 2) It uses the memory to store the experiences
# #### 3) We use this experience in training the neural network
# #### 4) We are using deque to insert new experiences and remove the old ones

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
from tensorflow import keras
from collections import deque
#from tensorflow.keras import models
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
import random
#%matplotlib inline

# %%
class Agent:
    def __init__(self,state_size,action_size):
        self.state_size = state_size
        self.action_size = action_size
        self.memory = deque(maxlen=2000)
        self.gamma = 0.95 #discount factor mentioned in bellman equations
        self.epsilon = 1.0 #100% exploration in the beginning
        self.epsilon_decay = 0.995
        self.epsilon_min = 0.01
        self.learning_rate = 0.001
        self.model = self._create_model()
        
    def _create_model(self):
        model = Sequential()
        model.add(Dense(24,input_dim=self.state_size,activation='relu'))
        model.add(Dense(24,activation='relu'))
        model.add(Dense(self.action_size,activation='linear'))
        model.compile(loss='mse',optimizer = Adam(learning_rate=self.learning_rate))
        return model
    def remember(self,state,action,reward,next_state,done):
        #remember past experiences
        self.memory.append((state,action,reward,next_state,done))
        
    def act(self,state):
        #smapling according to epsilon greedy method
        if np.random.rand()<=self.epsilon:
            return random.randrange(self.action_size)
        else:
            #ask neural network to give me the most suitable action
            return np.argmax(self.model.predict(state)[0])
    
    def train(self,batch_size=32):
        #training using replay buffer
        mini_batch = random.sample(self.memory,batch_size)
        for experience in mini_batch:
            state,action,reward,next_state,done = experience
            #expected reward
            if not done:
                #bellman eqaution to approximate target value to reward
                target =reward +self.gamma*np.amax(self.model.predict(next_state)[0])
            else:
                target = reward
            target_f   = self.model.predict(state)
            target_f[0][action] = target
            self.model.fit(state,target_f,epochs=1,verbose=0)
            
        if(self.epsilon>self.epsilon_min):
            self.epsilon *= self.epsilon_decay
    
    
    def load(self,name):
        self.model.load_weights(name)
            
    def save(self,name):
        self.model.save_weights(name)

# %% [markdown]
# #### 1) we are assuming Q(s,a) is a non-linear function and we are going to approximate
# #### it, learn it and minimize the MSE loss
# #### 2) we will approximate the target using bellman equations
# #### 3) we will use the stochastic gradient descent
# #### 4) Implement using replay buffer technique

# %%
# model  = Sequential()
# model.add(Dense(24,input_dim=4,activation='relu'))
# model.add(Dense(24,activation='relu'))
# model.add(Dense(2,activation='linear'))
# model.compile(loss='mse',optimizer = Adam(learning_rate=0.001))
# x = np.random.rand(1,4)
# model.predict(x)

# %% [markdown]
# ## Training DQN Agent (Deep Q learner)

# %%
n_episodes = 1000
output_dir = "cartpole_model/"

# %%
agent = Agent(state_size =4,action_size =2)
done = False
state_size =4
action_size = 2
batch_size = 32

# %%
for e in range (n_episodes):
    state = env.reset()
    state = np.reshape(state,[1,state_size])
    
    for time in range(500):
        env.render()
        action  = agent.act(state)
        next_state,reward,done,other_info = env.step(action)
        reward = reward if not done else -10
        next_state = np.reshape(next_state,[1,state_size])
        agent.remember(state,action,reward,next_state,done)
        state = next_state
        if done:
            print("Game Episode :{}/{}, High Score:{},Exploration Rate:{:.2}".format(e,n_episodes,time,agent.epsilon))
            break
            
    if len(agent.memory)>batch_size:
        agent.train(batch_size)
    
    if e%50==0:
        agent.save(output_dir+"weights_"+'{:04d}'.format(e)+".hdf5")
        
env.close()
# Out:
# Game Episode :0/1000, High Score:11,Exploration Rate:1.0
# Game Episode :1/1000, High Score:8,Exploration Rate:1.0
# Game Episode :2/1000, High Score:20,Exploration Rate:1.0
# Game Episode :3/1000, High Score:38,Exploration Rate:0.99
# Game Episode :4/1000, High Score:12,Exploration Rate:0.99
# Game Episode :5/1000, High Score:17,Exploration Rate:0.99
# Game Episode :6/1000, High Score:16,Exploration Rate:0.98
# Game Episode :7/1000, High Score:27,Exploration Rate:0.98
# Game Episode :8/1000, High Score:58,Exploration Rate:0.97
# Game Episode :9/1000, High Score:33,Exploration Rate:0.97
# Game Episode :10/1000, High Score:17,Exploration Rate:0.96
# Game Episode :11/1000, High Score:15,Exploration Rate:0.96
# Game Episode :12/1000, High Score:16,Exploration Rate:0.95
# Game Episode :13/1000, High Score:11,Exploration Rate:0.95
# Game Episode :14/1000, High Score:11,Exploration Rate:0.94
# Game Episode :15/1000, High Score:19,Exploration Rate:0.94
# Game Episode :16/1000, High Score:17,Exploration Rate:0.93
# Game Episode :17/1000, High Score:20,Exploration Rate:0.93
# Game Episode :18/1000, High Score:13,Exploration Rate:0.92
# Game Episode :19/1000, High Score:39,Exploration Rate:0.92
# Game Episode :20/1000, High Score:10,Exploration Rate:0.91
# Game Episode :21/1000, High Score:20,Exploration Rate:0.91
# Game Episode :22/1000, High Score:20,Exploration Rate:0.9
# Game Episode :23/1000, High Score:11,Exploration Rate:0.9
# Game Episode :24/1000, High Score:9,Exploration Rate:0.9
# Game Episode :25/1000, High Score:17,Exploration Rate:0.89
# Game Episode :26/1000, High Score:12,Exploration Rate:0.89
# Game Episode :27/1000, High Score:10,Exploration Rate:0.88
# Game Episode :28/1000, High Score:15,Exploration Rate:0.88
# Game Episode :29/1000, High Score:33,Exploration Rate:0.87
# Game Episode :30/1000, High Score:13,Exploration Rate:0.87
# Game Episode :31/1000, High Score:35,Exploration Rate:0.86
# Game Episode :32/1000, High Score:22,Exploration Rate:0.86
# Game Episode :33/1000, High Score:11,Exploration Rate:0.86
# Game Episode :34/1000, High Score:16,Exploration Rate:0.85
# Game Episode :35/1000, High Score:33,Exploration Rate:0.85
# Game Episode :36/1000, High Score:29,Exploration Rate:0.84
# Game Episode :37/1000, High Score:12,Exploration Rate:0.84
# Game Episode :38/1000, High Score:10,Exploration Rate:0.83
# Game Episode :39/1000, High Score:27,Exploration Rate:0.83
# Game Episode :40/1000, High Score:14,Exploration Rate:0.83
# Game Episode :41/1000, High Score:30,Exploration Rate:0.82
# Game Episode :42/1000, High Score:17,Exploration Rate:0.82
# Game Episode :43/1000, High Score:14,Exploration Rate:0.81
# Game Episode :44/1000, High Score:13,Exploration Rate:0.81
# Game Episode :45/1000, High Score:33,Exploration Rate:0.81
# Game Episode :46/1000, High Score:17,Exploration Rate:0.8
# Game Episode :47/1000, High Score:11,Exploration Rate:0.8
# Game Episode :48/1000, High Score:8,Exploration Rate:0.79
# Game Episode :49/1000, High Score:13,Exploration Rate:0.79
# Game Episode :50/1000, High Score:29,Exploration Rate:0.79
# Game Episode :51/1000, High Score:22,Exploration Rate:0.78
# Game Episode :52/1000, High Score:13,Exploration Rate:0.78
# Game Episode :53/1000, High Score:16,Exploration Rate:0.77
# Game Episode :54/1000, High Score:14,Exploration Rate:0.77
# Game Episode :55/1000, High Score:12,Exploration Rate:0.77
# Game Episode :56/1000, High Score:20,Exploration Rate:0.76
# Game Episode :57/1000, High Score:15,Exploration Rate:0.76
# Game Episode :58/1000, High Score:15,Exploration Rate:0.76
# Game Episode :59/1000, High Score:18,Exploration Rate:0.75
# Game Episode :60/1000, High Score:12,Exploration Rate:0.75
# Game Episode :61/1000, High Score:9,Exploration Rate:0.74
# Game Episode :62/1000, High Score:41,Exploration Rate:0.74
# Game Episode :63/1000, High Score:16,Exploration Rate:0.74
# Game Episode :64/1000, High Score:12,Exploration Rate:0.73
# Game Episode :65/1000, High Score:12,Exploration Rate:0.73
# Game Episode :66/1000, High Score:8,Exploration Rate:0.73
# Game Episode :67/1000, High Score:11,Exploration Rate:0.72
# Game Episode :68/1000, High Score:12,Exploration Rate:0.72
# Game Episode :69/1000, High Score:9,Exploration Rate:0.71
# Game Episode :70/1000, High Score:12,Exploration Rate:0.71
# Game Episode :71/1000, High Score:9,Exploration Rate:0.71
# Game Episode :72/1000, High Score:10,Exploration Rate:0.7
# Game Episode :73/1000, High Score:12,Exploration Rate:0.7
# Game Episode :74/1000, High Score:10,Exploration Rate:0.7
# Game Episode :75/1000, High Score:10,Exploration Rate:0.69
# Game Episode :76/1000, High Score:9,Exploration Rate:0.69
# Game Episode :77/1000, High Score:26,Exploration Rate:0.69
# Game Episode :78/1000, High Score:14,Exploration Rate:0.68
# Game Episode :79/1000, High Score:8,Exploration Rate:0.68
# Game Episode :80/1000, High Score:12,Exploration Rate:0.68
# Game Episode :81/1000, High Score:19,Exploration Rate:0.67
# Game Episode :82/1000, High Score:16,Exploration Rate:0.67
# Game Episode :83/1000, High Score:11,Exploration Rate:0.67
# Game Episode :84/1000, High Score:12,Exploration Rate:0.66
# Game Episode :85/1000, High Score:10,Exploration Rate:0.66
# Game Episode :86/1000, High Score:19,Exploration Rate:0.66
# Game Episode :87/1000, High Score:9,Exploration Rate:0.65
# Game Episode :88/1000, High Score:9,Exploration Rate:0.65
# Game Episode :89/1000, High Score:13,Exploration Rate:0.65
# Game Episode :90/1000, High Score:11,Exploration Rate:0.64
# Game Episode :91/1000, High Score:18,Exploration Rate:0.64
# Game Episode :92/1000, High Score:8,Exploration Rate:0.64
# Game Episode :93/1000, High Score:15,Exploration Rate:0.63
# Game Episode :94/1000, High Score:12,Exploration Rate:0.63
# Game Episode :95/1000, High Score:22,Exploration Rate:0.63
# Game Episode :96/1000, High Score:10,Exploration Rate:0.62
# Game Episode :97/1000, High Score:16,Exploration Rate:0.62
# Game Episode :98/1000, High Score:15,Exploration Rate:0.62
# Game Episode :99/1000, High Score:12,Exploration Rate:0.61
# Game Episode :100/1000, High Score:7,Exploration Rate:0.61
# Game Episode :101/1000, High Score:17,Exploration Rate:0.61
# Game Episode :102/1000, High Score:11,Exploration Rate:0.61
# Game Episode :103/1000, High Score:11,Exploration Rate:0.6
# Game Episode :104/1000, High Score:12,Exploration Rate:0.6
# Game Episode :105/1000, High Score:13,Exploration Rate:0.6
# Game Episode :106/1000, High Score:15,Exploration Rate:0.59
# Game Episode :107/1000, High Score:15,Exploration Rate:0.59
# Game Episode :108/1000, High Score:8,Exploration Rate:0.59
# Game Episode :109/1000, High Score:12,Exploration Rate:0.58
# Game Episode :110/1000, High Score:9,Exploration Rate:0.58
# Game Episode :111/1000, High Score:12,Exploration Rate:0.58
# Game Episode :112/1000, High Score:11,Exploration Rate:0.58
# Game Episode :113/1000, High Score:18,Exploration Rate:0.57
# Game Episode :114/1000, High Score:12,Exploration Rate:0.57
# Game Episode :115/1000, High Score:7,Exploration Rate:0.57
# Game Episode :116/1000, High Score:14,Exploration Rate:0.56
# Game Episode :117/1000, High Score:10,Exploration Rate:0.56
# Game Episode :118/1000, High Score:20,Exploration Rate:0.56
# Game Episode :119/1000, High Score:21,Exploration Rate:0.56
# Game Episode :120/1000, High Score:14,Exploration Rate:0.55
# Game Episode :121/1000, High Score:12,Exploration Rate:0.55
# Game Episode :122/1000, High Score:9,Exploration Rate:0.55
# Game Episode :123/1000, High Score:11,Exploration Rate:0.55
# Game Episode :124/1000, High Score:16,Exploration Rate:0.54
# Game Episode :125/1000, High Score:12,Exploration Rate:0.54
# Game Episode :126/1000, High Score:37,Exploration Rate:0.54
# Game Episode :127/1000, High Score:39,Exploration Rate:0.53
# Game Episode :128/1000, High Score:33,Exploration Rate:0.53
# Game Episode :129/1000, High Score:32,Exploration Rate:0.53
# Game Episode :130/1000, High Score:18,Exploration Rate:0.53
# Game Episode :131/1000, High Score:20,Exploration Rate:0.52
# Game Episode :132/1000, High Score:20,Exploration Rate:0.52
# Game Episode :133/1000, High Score:16,Exploration Rate:0.52
# Game Episode :134/1000, High Score:13,Exploration Rate:0.52
# Game Episode :135/1000, High Score:35,Exploration Rate:0.51
# Game Episode :136/1000, High Score:29,Exploration Rate:0.51
# Game Episode :137/1000, High Score:104,Exploration Rate:0.51
# Game Episode :138/1000, High Score:21,Exploration Rate:0.51
# Game Episode :139/1000, High Score:31,Exploration Rate:0.5
# Game Episode :140/1000, High Score:73,Exploration Rate:0.5
# Game Episode :141/1000, High Score:34,Exploration Rate:0.5
# Game Episode :142/1000, High Score:12,Exploration Rate:0.5
# Game Episode :143/1000, High Score:12,Exploration Rate:0.49
# Game Episode :144/1000, High Score:40,Exploration Rate:0.49
# Game Episode :145/1000, High Score:18,Exploration Rate:0.49
# Game Episode :146/1000, High Score:12,Exploration Rate:0.49
# Game Episode :147/1000, High Score:18,Exploration Rate:0.48
# Game Episode :148/1000, High Score:19,Exploration Rate:0.48
# Game Episode :149/1000, High Score:10,Exploration Rate:0.48
# Game Episode :150/1000, High Score:15,Exploration Rate:0.48
# Game Episode :151/1000, High Score:22,Exploration Rate:0.47
# Game Episode :152/1000, High Score:35,Exploration Rate:0.47
# Game Episode :153/1000, High Score:21,Exploration Rate:0.47
# Game Episode :154/1000, High Score:34,Exploration Rate:0.47
# Game Episode :155/1000, High Score:30,Exploration Rate:0.46
# Game Episode :156/1000, High Score:31,Exploration Rate:0.46
# Game Episode :157/1000, High Score:27,Exploration Rate:0.46
# Game Episode :158/1000, High Score:60,Exploration Rate:0.46
# Game Episode :159/1000, High Score:34,Exploration Rate:0.46
# Game Episode :160/1000, High Score:62,Exploration Rate:0.45
# Game Episode :161/1000, High Score:39,Exploration Rate:0.45
# Game Episode :162/1000, High Score:30,Exploration Rate:0.45
# Game Episode :163/1000, High Score:41,Exploration Rate:0.45
# Game Episode :164/1000, High Score:25,Exploration Rate:0.44
# Game Episode :165/1000, High Score:18,Exploration Rate:0.44
# Game Episode :166/1000, High Score:55,Exploration Rate:0.44
# Game Episode :167/1000, High Score:14,Exploration Rate:0.44
# Game Episode :168/1000, High Score:12,Exploration Rate:0.44
# Game Episode :169/1000, High Score:22,Exploration Rate:0.43
# Game Episode :170/1000, High Score:15,Exploration Rate:0.43
# Game Episode :171/1000, High Score:26,Exploration Rate:0.43
# Game Episode :172/1000, High Score:25,Exploration Rate:0.43
# Game Episode :173/1000, High Score:13,Exploration Rate:0.42
# Game Episode :174/1000, High Score:40,Exploration Rate:0.42
# Game Episode :175/1000, High Score:38,Exploration Rate:0.42
# Game Episode :176/1000, High Score:79,Exploration Rate:0.42
# Game Episode :177/1000, High Score:71,Exploration Rate:0.42
# Game Episode :178/1000, High Score:16,Exploration Rate:0.41
# Game Episode :179/1000, High Score:31,Exploration Rate:0.41
# Game Episode :180/1000, High Score:21,Exploration Rate:0.41
# Game Episode :181/1000, High Score:38,Exploration Rate:0.41
# Game Episode :182/1000, High Score:14,Exploration Rate:0.41
# Game Episode :183/1000, High Score:16,Exploration Rate:0.4
# Game Episode :184/1000, High Score:43,Exploration Rate:0.4
# Game Episode :185/1000, High Score:26,Exploration Rate:0.4
# Game Episode :186/1000, High Score:47,Exploration Rate:0.4
# Game Episode :187/1000, High Score:27,Exploration Rate:0.4
# Game Episode :188/1000, High Score:46,Exploration Rate:0.39
# Game Episode :189/1000, High Score:18,Exploration Rate:0.39
# Game Episode :190/1000, High Score:15,Exploration Rate:0.39
# Game Episode :191/1000, High Score:87,Exploration Rate:0.39
# Game Episode :192/1000, High Score:19,Exploration Rate:0.39
# Game Episode :193/1000, High Score:14,Exploration Rate:0.38
# Game Episode :194/1000, High Score:14,Exploration Rate:0.38
# Game Episode :195/1000, High Score:18,Exploration Rate:0.38
# Game Episode :196/1000, High Score:30,Exploration Rate:0.38
# Game Episode :197/1000, High Score:51,Exploration Rate:0.38
# Game Episode :198/1000, High Score:42,Exploration Rate:0.37
# Game Episode :199/1000, High Score:24,Exploration Rate:0.37
# Game Episode :200/1000, High Score:12,Exploration Rate:0.37
# Game Episode :201/1000, High Score:24,Exploration Rate:0.37
# Game Episode :202/1000, High Score:29,Exploration Rate:0.37
# Game Episode :203/1000, High Score:77,Exploration Rate:0.37
# Game Episode :204/1000, High Score:51,Exploration Rate:0.36
# Game Episode :205/1000, High Score:20,Exploration Rate:0.36
# Game Episode :206/1000, High Score:27,Exploration Rate:0.36
# Game Episode :207/1000, High Score:46,Exploration Rate:0.36
# Game Episode :208/1000, High Score:66,Exploration Rate:0.36
# Game Episode :209/1000, High Score:97,Exploration Rate:0.35
# Game Episode :210/1000, High Score:21,Exploration Rate:0.35
# Game Episode :211/1000, High Score:142,Exploration Rate:0.35
# Game Episode :212/1000, High Score:23,Exploration Rate:0.35
# Game Episode :213/1000, High Score:38,Exploration Rate:0.35
# Game Episode :214/1000, High Score:40,Exploration Rate:0.35
# Game Episode :215/1000, High Score:106,Exploration Rate:0.34
# Game Episode :216/1000, High Score:62,Exploration Rate:0.34
# Game Episode :217/1000, High Score:126,Exploration Rate:0.34
# Game Episode :218/1000, High Score:28,Exploration Rate:0.34
# Game Episode :219/1000, High Score:72,Exploration Rate:0.34
# Game Episode :220/1000, High Score:50,Exploration Rate:0.34
# Game Episode :221/1000, High Score:83,Exploration Rate:0.33
# Game Episode :222/1000, High Score:66,Exploration Rate:0.33
# Game Episode :223/1000, High Score:55,Exploration Rate:0.33
# Game Episode :224/1000, High Score:70,Exploration Rate:0.33
# Game Episode :225/1000, High Score:67,Exploration Rate:0.33
# Game Episode :226/1000, High Score:45,Exploration Rate:0.33
# Game Episode :227/1000, High Score:92,Exploration Rate:0.32
# Game Episode :228/1000, High Score:48,Exploration Rate:0.32
# Game Episode :229/1000, High Score:23,Exploration Rate:0.32
# Game Episode :230/1000, High Score:38,Exploration Rate:0.32
# Game Episode :231/1000, High Score:43,Exploration Rate:0.32
# Game Episode :232/1000, High Score:28,Exploration Rate:0.32
# Game Episode :233/1000, High Score:53,Exploration Rate:0.31
# Game Episode :234/1000, High Score:27,Exploration Rate:0.31
# Game Episode :235/1000, High Score:36,Exploration Rate:0.31
# Game Episode :236/1000, High Score:113,Exploration Rate:0.31
